# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\94-95_Player_Stats.csv")

# %%
#Adding ORL as it relocates East
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'MIL'), (df['Tm'] == 'WSB'), (df['Tm'] == 'CHI'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'NJN'), (df['Tm'] == 'DET'), (df['Tm'] == 'MIA'),
    (df['Tm'] == 'CHH'), (df['Tm'] == 'ORL')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East', 'East', 'East', 'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                        Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 0      1      Alaa Abdelnaby\abdelal01  PF   26  TOT  54   0   506  118   231
# 1      1      Alaa Abdelnaby\abdelal01  PF   26  SAC  51   0   476  117   220
# 2      1      Alaa Abdelnaby\abdelal01  PF   26  PHI   3   0    30    1    11
# 3      2  Mahmoud Abdul-Rauf\abdulma02  PG   25  DEN  73  43  2082  472  1005
# 4      3       Michael Adams\adamsmi01  PG   32  CHH  29   0   443   67   148
# 5      4      Rafael Addison\addisra01  SF   30  DET  79  16  1776  279   586
# 6      5         Danny Ainge\aingeda01  SG   35  PHO  74   1  1374  194   422
# 7      6    Victor Alexander\alexavi01   C   25  GSW  50  29  1237  230   447
# 8      7      Derrick Alston\alstode01   C   22  PHI  64   1  1032  120   258
# 9      8       Greg Anderson\andergr01  PF   30  ATL  51   0   622   57   104
# 10     9      Kenny Anderson\anderke01  PG   24  NJN  72  70  2689  411  1031
# ...

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks with Conferences\\94-95_Player_Conferences.csv', index = False)
