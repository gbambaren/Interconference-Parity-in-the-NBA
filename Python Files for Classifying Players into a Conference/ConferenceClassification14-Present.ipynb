# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\17-18_Player_Stats.csv")

# %%
#CHA with CHO due to Charlotte rename into Hornets.
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'MIL'), (df['Tm'] == 'WAS'), (df['Tm'] == 'CHI'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'BRK'), (df['Tm'] == 'DET'), (df['Tm'] == 'MIA'),
    (df['Tm'] == 'CHO'), (df['Tm'] == 'ORL'), (df['Tm'] == 'TOR')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East', 'East', 'East', 'East', 'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                           Player Pos  Age   Tm   G    MP   PER  \
# 0      1           Alex Abrines\abrinal01  SG   24  OKC  75  1134   9.0
# 1      2               Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2
# 2      3           Steven Adams\adamsst01   C   24  OKC  76  2487  20.6
# 3      4            Bam Adebayo\adebaba01   C   20  MIA  69  1368  15.7
# 4      5          Arron Afflalo\afflaar01  SG   32  ORL  53   682   5.8
# 5      6           Cole Aldrich\aldrico01   C   29  MIN  21    49   6.0
# 6      7      LaMarcus Aldridge\aldrila01   C   32  SAS  75  2509  25.0
# 7      8          Jarrett Allen\allenja01   C   19  BRK  72  1441  17.5
# 8      9           Kadeem Allen\allenka01  PG   25  BOS  18   107   2.6
# 9     10             Tony Allen\allento01  SF   36  NOP  22   273   8.7
# 10    11        Al-Farouq Aminu\aminual01  PF   27  POR  69  2072  12.0
# 11    12        Justin Anderson\anderju01  SF   24  PHI  38   519  13.0
# ...

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\New Player Ranks with Conferences\\17-18_Player_Conferences.csv', index = False)
