# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\13-14_Player_Stats.csv")

# %%
#NJN with BRK due to relocation from New Jersey to Brooklyn.
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'MIL'), (df['Tm'] == 'WAS'), (df['Tm'] == 'CHI'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'BRK'), (df['Tm'] == 'DET'), (df['Tm'] == 'MIA'),
    (df['Tm'] == 'CHA'), (df['Tm'] == 'ORL'), (df['Tm'] == 'TOR')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East', 'East', 'East', 'East', 'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                           Player    Pos  Age   Tm   G  GS    MP   FG  \
# 0      1               Quincy Acy\acyqu01     SF   23  TOT  63   0   847   66
# 1      1               Quincy Acy\acyqu01     SF   23  TOR   7   0    61    6
# 2      1               Quincy Acy\acyqu01     SF   23  SAC  56   0   786   60
# 3      2           Steven Adams\adamsst01      C   20  OKC  81  20  1197   93
# 4      3            Jeff Adrien\adrieje01     PF   27  TOT  53  12   961  143
# 5      3            Jeff Adrien\adrieje01     PF   27  CHA  25   0   256   22
# 6      3            Jeff Adrien\adrieje01     PF   27  MIL  28  12   705  121
# 7      4          Arron Afflalo\afflaar01     SG   28  ORL  73  73  2552  464
# 8      5          Alexis Ajinca\ajincal01      C   25  NOP  56  30   951  136
# 9      6           Cole Aldrich\aldrico01      C   25  NYK  46   2   330   33
# 10     7      LaMarcus Aldridge\aldrila01     PF   28  POR  69  69  2498  652
# ...

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks with Conferences\\13-14_Player_Conferences.csv', index = False)
