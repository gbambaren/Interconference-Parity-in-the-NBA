# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\09-10_Player_Stats.csv")

# %%
#Replacing NOH with CHA due to CHA joining the East and NOH moving to the West.
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'MIL'), (df['Tm'] == 'WAS'), (df['Tm'] == 'CHI'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'NJN'), (df['Tm'] == 'DET'), (df['Tm'] == 'MIA'),
    (df['Tm'] == 'CHA'), (df['Tm'] == 'ORL'), (df['Tm'] == 'TOR')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East', 'East', 'East', 'East', 'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                       Player   Pos  Age   Tm   G    MP   PER    TS%  \
# 0      1      Arron Afflalo\afflaar01    SG   24  DEN  82  2221  10.9  0.576
# 1      2      Alexis Ajinca\ajincal01     C   21  CHA   6    30   6.3  0.479
# 2      3  LaMarcus Aldridge\aldrila01    PF   24  POR  78  2922  18.2  0.535
# 3      4      Joe Alexander\alexajo01    SF   23  CHI   8    29   2.8  0.273
# 4      5        Malik Allen\allenma01    PF   31  DEN  51   456   5.9  0.431
# 5      6         Ray Allen*\allenra02    SG   34  BOS  80  2819  15.2  0.601
# 6      7         Tony Allen\allento01    SG   28  BOS  54   889  14.2  0.540
# 7      8       Rafer Alston\alstora01    PG   33  TOT  52  1421   8.2  0.443
# 8      8       Rafer Alston\alstora01    PG   33  NJN  27   766   8.7  0.436
# 9      8       Rafer Alston\alstora01    PG   33  MIA  25   655   7.7  0.456
# 10     9       Lou Amundson\amundlo01    PF   27  PHO  79  1168  14.4  0.562
# ...

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\New Player Ranks with Conferences\\09-09_Player_Conferences.csv', index = False)
