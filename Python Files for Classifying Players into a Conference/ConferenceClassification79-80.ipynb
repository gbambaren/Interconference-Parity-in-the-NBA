# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\79-80_Player_Stats.csv")

# %%
#Replacing NOJ with IND due to the conference swap between both teams
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'HOU'), (df['Tm'] == 'WSB'), (df['Tm'] == 'SAS'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'NJN'), (df['Tm'] == 'DET')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                          Player Pos  Age   Tm   G    GS    MP   FG  \
# 0      1  Kareem Abdul-Jabbar*\abdulka01   C   32  LAL  82   NaN  3143  835
# 1      2         Tom Abernethy\abernto01  PF   25  GSW  67   NaN  1222  153
# 2      3           Alvan Adams\adamsal01   C   25  PHO  75   NaN  2168  465
# 3      4       Tiny Archibald*\architi01  PG   31  BOS  80  80.0  2864  383
# 4      5         Dennis Awtrey\awtrede01   C   31  CHI  26   NaN   560   27
# 5      6            Gus Bailey\bailegu01  SG   28  WSB  20   NaN   180   16
# 6      7          James Bailey\baileja01  PF   22  SEA  67   NaN   726  122
# 7      8          Greg Ballard\ballagr01  SF   25  WSB  82   NaN  2438  545
# 8      9           Mike Bantom\bantomi01  SF   28  IND  77   NaN  2330  384
# 9     10         Marvin Barnes\barnema01  PF   27  SDC  20   NaN   287   24
# 10    11           Rick Barry*\barryri01  SF   35  HOU  72   NaN  1816  325
# ...

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks with Conferences\\79-80_Player_Conferences.csv', index = False)
