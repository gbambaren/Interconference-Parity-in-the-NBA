# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\96-97_Player_Stats.csv")

# %%
#Adding TOR as it joins the East.
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'MIL'), (df['Tm'] == 'WSB'), (df['Tm'] == 'CHI'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'NJN'), (df['Tm'] == 'DET'), (df['Tm'] == 'MIA'),
    (df['Tm'] == 'CHH'), (df['Tm'] == 'ORL'), (df['Tm'] == 'TOR')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East', 'East', 'East', 'East', 'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                         Player   Pos  Age   Tm   G  GS    MP   FG  \
# 0      1   Mahmoud Abdul-Rauf\abdulma02    PG   27  SAC  75  51  2131  411
# 1      2  Shareef Abdur-Rahim\abdursh01    PF   20  VAN  80  71  2802  550
# 2      3       Rafael Addison\addisra01    SF   32  CHH  41   3   355   49
# 3      4       Cory Alexander\alexaco01    PG   23  SAS  80   6  1454  194
# 4      5         Jerome Allen\allenje01    SG   24  TOT  76   1   943   78
# 5      5         Jerome Allen\allenje01    SG   24  IND  51   1   692   57
# 6      5         Jerome Allen\allenje01    SG   24  DEN  25   0   251   21
# 7      6           Ray Allen*\allenra02    SG   21  MIL  82  81  2532  390
# 8      7       Derrick Alston\alstode01     C   24  ATL   2   0    11    0
# 9      8         Ashraf Amaya\amayaas01    PF   25  WSB  31   0   144   12
# 10     9        Greg Anderson\andergr01     C   32  SAS  82  48  1659  130
# ...

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks with Conferences\\96-97_Player_Conferences.csv', index = False)
