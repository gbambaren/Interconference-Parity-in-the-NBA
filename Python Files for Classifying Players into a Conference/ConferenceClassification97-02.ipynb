# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\01-02_Player_Stats.csv")

# %%
#Replacing WSB with WAS, due to the team's rename.
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'MIL'), (df['Tm'] == 'WAS'), (df['Tm'] == 'CHI'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'NJN'), (df['Tm'] == 'DET'), (df['Tm'] == 'MIA'),
    (df['Tm'] == 'CHH'), (df['Tm'] == 'ORL'), (df['Tm'] == 'TOR')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East', 'East', 'East', 'East', 'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                           Player Pos  Age   Tm   G    MP   PER  \
# 0      1      Tariq Abdul-Wahad\abdulta01  SG   27  TOT  24   441   9.8
# 1      1      Tariq Abdul-Wahad\abdulta01  SG   27  DEN  20   417  10.3
# 2      1      Tariq Abdul-Wahad\abdulta01  SG   27  DAL   4    24   0.3
# 3      2    Shareef Abdur-Rahim\abdursh01  PF   25  ATL  77  2980  19.8
# 4      3     Courtney Alexander\alexaco02  SG   24  WAS  56  1325  13.6
# 5      4       Victor Alexander\alexavi01   C   32  DET  15    97   9.2
# 6      5            Malik Allen\allenma01  PF   23  MIA  12   161  15.0
# 7      6             Ray Allen*\allenra02  SG   26  MIL  69  2525  21.6
# 8      7           Rafer Alston\alstora01  PG   25  MIL  50   600  13.9
# 9      8           John Amaechi\amaecjo01  PF   31  UTA  54   586   5.4
# 10     9         Chris Andersen\anderch01   C   23  DEN  24   262  13.8
# 11    10         Derek Anderson\anderde01  SG   27  POR  70  1860  15.5
# ...

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\New Player Ranks with Conferences\\01-02_Player_Conferences.csv', index = False)
