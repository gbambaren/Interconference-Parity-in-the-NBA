# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt
from pandas.tools.plotting import autocorrelation_plot
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("West.csv")
df['Year']=pd.to_datetime(df['Year'], format="%Y")
df.set_index('Year', inplace=True)
df = df.iloc[::-1, :]
df.head()
# Out:
#              BPM  DBPM  OBPM    PER  VORP     WS Moved_to  West +/-
# Year
# 1978-01-01 -36.7 -12.5 -24.3    0.0   6.5   46.7     West        46
# 1979-01-01 -72.4 -28.5 -44.3  -61.0  19.0   82.3     West        52
# 1980-01-01 -84.2  -8.0 -76.1 -100.8   7.4   69.3     West        -6
# 1981-01-01 -38.4  -8.3 -30.0  -58.5  35.5  149.8     West       -30
# 1982-01-01 -30.0  -4.3 -25.8  -21.2   2.3   33.0     West       -20

# %%
df.plot()
plt.show()

# %%
model = ARIMA(df['West +/-'], order=(2, 1, 0))
model_fit=model.fit(trend='nc')
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:             D.West +/-   No. Observations:                   40
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                -200.713
# Method:                       css-mle   S.D. of innovations             36.438
# Date:                Sat, 24 Nov 2018   AIC                            407.426
# Time:                        15:26:27   BIC                            412.493
# Sample:                    01-01-1979   HQIC                           409.258
#                          - 01-01-2018
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ar.L1.D.West +/-    -0.1191      0.147     -0.807      0.424      -0.408       0.170
# ar.L2.D.West +/-    -0.3455      0.149     -2.322      0.026      -0.637      -0.054
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.1723           -1.6926j            1.7013           -0.2661
# AR.2           -0.1723           +1.6926j            1.7013            0.2661
# -----------------------------------------------------------------------------
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]

# %%
model = ARIMA(df['BPM'], order=(2, 1, 0))
model_fit=model.fit(trend='nc')
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                  D.BPM   No. Observations:                   40
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                -216.641
# Method:                       css-mle   S.D. of innovations             54.140
# Date:                Sat, 24 Nov 2018   AIC                            439.283
# Time:                        15:27:37   BIC                            444.349
# Sample:                    01-01-1979   HQIC                           441.115
#                          - 01-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ar.L1.D.BPM    -0.3888      0.144     -2.706      0.010      -0.670      -0.107
# ar.L2.D.BPM    -0.4071      0.143     -2.845      0.007      -0.688      -0.127
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.4775           -1.4928j            1.5673           -0.2993
# AR.2           -0.4775           +1.4928j            1.5673            0.2993
# -----------------------------------------------------------------------------
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]

# %%
model = ARIMA(df['WS'], order=(2, 1, 0))
model_fit=model.fit(trend='nc')
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D.WS   No. Observations:                   40
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                -195.335
# Method:                       css-mle   S.D. of innovations             31.796
# Date:                Sat, 24 Nov 2018   AIC                            396.670
# Time:                        15:28:18   BIC                            401.737
# Sample:                    01-01-1979   HQIC                           398.502
#                          - 01-01-2018
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1.D.WS    -0.6248      0.157     -3.991      0.000      -0.932      -0.318
# ar.L2.D.WS    -0.1027      0.156     -0.660      0.513      -0.408       0.202
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -3.0405           -0.6990j            3.1198           -0.4640
# AR.2           -3.0405           +0.6990j            3.1198            0.4640
# -----------------------------------------------------------------------------
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]

# %%
model = ARIMA(df['VORP'], order=(2, 1, 0))
model_fit=model.fit(trend='nc')
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.VORP   No. Observations:                   40
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                -144.926
# Method:                       css-mle   S.D. of innovations              8.973
# Date:                Sat, 24 Nov 2018   AIC                            295.851
# Time:                        15:28:33   BIC                            300.918
# Sample:                    01-01-1979   HQIC                           297.683
#                          - 01-01-2018
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ar.L1.D.VORP    -0.8749      0.156     -5.616      0.000      -1.180      -0.570
# ar.L2.D.VORP    -0.2557      0.156     -1.638      0.110      -0.562       0.050
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.7110           -0.9919j            1.9777           -0.4164
# AR.2           -1.7110           +0.9919j            1.9777            0.4164
# -----------------------------------------------------------------------------
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]

# %%
model = ARIMA(df['PER'], order=(2, 1, 0))
model_fit=model.fit(trend='nc')
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                  D.PER   No. Observations:                   40
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                -220.836
# Method:                       css-mle   S.D. of innovations             60.121
# Date:                Sat, 24 Nov 2018   AIC                            447.672
# Time:                        15:28:41   BIC                            452.739
# Sample:                    01-01-1979   HQIC                           449.504
#                          - 01-01-2018
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ar.L1.D.PER    -0.4378      0.147     -2.986      0.005      -0.725      -0.150
# ar.L2.D.PER    -0.3979      0.148     -2.693      0.010      -0.687      -0.108
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.5501           -1.4868j            1.5853           -0.3064
# AR.2           -0.5501           +1.4868j            1.5853            0.3064
# -----------------------------------------------------------------------------
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]

# %%
X = df['West +/-']
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(2,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot

plt.plot(predictions, color='red' )
plt.show()
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\Users\Daniel\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]
# predicted=106.466452, expected=62.000000
# predicted=56.231869, expected=54.000000
# predicted=69.900997, expected=64.000000
# predicted=67.234124, expected=66.000000
# predicted=64.452070, expected=-12.000000
# predicted=-11.385820, expected=42.000000
# predicted=58.595413, expected=72.000000
# predicted=52.781007, expected=42.000000
# predicted=36.060664, expected=74.000000
# predicted=80.407098, expected=118.000000
# predicted=105.251629, expected=76.000000
# predicted=68.406389, expected=14.000000
# predicted=36.526691, expected=42.000000
# predicted=63.583446, expected=24.000000
# Test MSE: 1376.758

# %%
plt.plot(test)
